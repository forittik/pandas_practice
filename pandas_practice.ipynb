# %% [markdown]
# # Date-27/07/2024 (Day-1)

# %% [markdown]
# ### For any help use (pandas documentation)
#
# * For eg- if you need help regarding pivot table then search ( Pandas.pivot_table documentation)
#
# * shift+tab (to seek help)

# %%
import pandas as pd
df=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/nyc_weather.csv")

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
#what is the maximum temperature?
df["Temperature"].max()
# Out:
# 50

# %%
# which day it was raining?

df["EST"][df["Events"]=="Rain"]
# Out:
# 8      1/9/2016
# 9     1/10/2016
# 15    1/16/2016
# 26    1/27/2016
# Name: EST, dtype: object

# %%
# what is the average wind speed?
df["WindSpeedMPH"].mean()
# Out:
# 6.892857142857143

# %%
# Data munging and data wrangling
# nothing but processing and cleaning the data

df["WindSpeedMPH"].fillna(0,inplace=True)
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_13108/1922518287.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["WindSpeedMPH"].fillna(0,inplace=True)

# %%
df["WindSpeedMPH"].mean()
# Out:
# 6.225806451612903

# %%
nyc_weather={'temp':[1,2,3,4],
            'date':['12/12/2023','10/9/2001','3/3/2021','14/8/2001'],
            'name':["raja","lolit","mili","priya"],
            'event':["rain","sun","cloud","rain"],
            'windspeed':[2,3,4,5]}
df1=pd.DataFrame(nyc_weather)

# %%
df1
# Out:
#    temp        date   name  event  windspeed
# 0     1  12/12/2023   raja   rain          2
# 1     2   10/9/2001  lolit    sun          3
# 2     3    3/3/2021   mili  cloud          4
# 3     4   14/8/2001  priya   rain          5

# %%
#wrong
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7428/1521958372.py in <module>
#       1 #wrong
# ----> 2 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
#right
df.shape
# Out:
# (31, 11)

# %%
col,row=df.shape
print(col)
print(row)
# Out:
# 31
# 11

# %%
df1[2:]
# Out:
#    temp       date   name  event  windspeed
# 2     3   3/3/2021   mili  cloud          4
# 3     4  14/8/2001  priya   rain          5

# %%
df1["temp"][2]
# Out:
# 3

# %%
# how to print the number of columns
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='object')

# %%
# how to print a particular column
df1.date
# Out:
# 0    12/12/2023
# 1     10/9/2001
# 2      3/3/2021
# 3     14/8/2001
# Name: date, dtype: object

# %%
df1["date"]
# Out:
# 0    12/12/2023
# 1     10/9/2001
# 2      3/3/2021
# 3     14/8/2001
# Name: date, dtype: object

# %%
# type of data frame is pandas core series series
type(df1["temp"])
# Out:
# pandas.core.series.Series

# %%
# how to print two or more columns side by side
df1[["temp","date"]]
# Out:
#    temp        date
# 0     1  12/12/2023
# 1     2   10/9/2001
# 2     3    3/3/2021
# 3     4   14/8/2001

# %%
df.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
# suppose from your dataset you want to find the highest temperature
df.Temperature.max() #or# df["Temperature"].max()
# Out:
# 50

# %%
# how to find the statistics of your data frame
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     31.000000   31.000000       31.000000
# mean          9.193548      6.225806    3.129032      247.129032
# std           1.939405      3.422569    2.629853       92.308086
# min           1.000000      0.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
# give me rows which have temperature more than or equal to 32?
df[df["Temperature"]>=32]
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# ...

# %%
#Get the row where tmperature is maximum
df[df["Temperature"]==df["Temperature"].max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           0.0             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
#get only event column for maximum temperature
df["Events"][df["Temperature"]==df["Temperature"].max()]
# Out:
# 9    Rain
# Name: Events, dtype: object

# %%
#get more than one column for maximum temperature
df[["EST","Events"]][df["Temperature"]==df["Temperature"].max()]
# Out:
#          EST Events
# 9  1/10/2016   Rain

# %%
df.index
# Out:
# RangeIndex(start=0, stop=31, step=1)

# %%
df1
# Out:
#    temp        date   name  event  windspeed
# 0     1  12/12/2023   raja   rain          2
# 1     2   10/9/2001  lolit    sun          3
# 2     3    3/3/2021   mili  cloud          4
# 3     4   14/8/2001  priya   rain          5

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
# how to set/change the index
df1.set_index("temp")
# Out:
#             date   name  event  windspeed
# temp
# 1     12/12/2023   raja   rain          2
# 2      10/9/2001  lolit    sun          3
# 3       3/3/2021   mili  cloud          4
# 4      14/8/2001  priya   rain          5

# %%
# but if you run df1 it will show the same as prev, will not get updated
df1
# Out:
#    temp        date   name  event  windspeed
# 0     1  12/12/2023   raja   rain          2
# 1     2   10/9/2001  lolit    sun          3
# 2     3    3/3/2021   mili  cloud          4
# 3     4   14/8/2001  priya   rain          5

# %%
#so for this we have to (inplace=True)
df1.set_index("temp",inplace=True)

# %%
df1
# Out:
#             date   name  event  windspeed
# temp
# 1     12/12/2023   raja   rain          2
# 2      10/9/2001  lolit    sun          3
# 3       3/3/2021   mili  cloud          4
# 4      14/8/2001  priya   rain          5

# %%
#gives output the given label
df1.loc[2]
# Out:
# date         10/9/2001
# name             lolit
# event              sun
# windspeed            3
# Name: 2, dtype: object

# %%
df1.loc[1:3]
# Out:
#             date   name  event  windspeed
# temp
# 1     12/12/2023   raja   rain          2
# 2      10/9/2001  lolit    sun          3
# 3       3/3/2021   mili  cloud          4

# %%
#gives the output of the given position
df1.iloc[2]
# Out:
# date         3/3/2021
# name             mili
# event           cloud
# windspeed           4
# Name: 3, dtype: object

# %%
df1.iloc[1:3]
# Out:
#            date   name  event  windspeed
# temp
# 2     10/9/2001  lolit    sun          3
# 3      3/3/2021   mili  cloud          4

# %%
# how to reset the index
# but it will not get updated until we use inplace=True
#df1.reset_index("temp")
# if you run this more than onwe times it will not work beause it will get reset to the original one at first when you rum reset
df1.reset_index("temp",inplace=True)

# %%
df1
# Out:
#    temp        date   name  event  windspeed
# 0     1  12/12/2023   raja   rain          2
# 1     2   10/9/2001  lolit    sun          3
# 2     3    3/3/2021   mili  cloud          4
# 3     4   14/8/2001  priya   rain          5

# %%
df1.loc[1:3]
# Out:
#    temp       date   name  event  windspeed
# 1     2  10/9/2001  lolit    sun          3
# 2     3   3/3/2021   mili  cloud          4
# 3     4  14/8/2001  priya   rain          5

# %%
df1.iloc[1:3]
# Out:
#    temp       date   name  event  windspeed
# 1     2  10/9/2001  lolit    sun          3
# 2     3   3/3/2021   mili  cloud          4

# %% [markdown]
# ## Date- 27/07/2024 (Day-2)

# %%
# Using stock data
import pandas as pd
df2=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data.csv")

# %%
df2.head()
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# ### Incase you have an unnecessary header
# ### How will you remove that (check below image)
# ![image.png](attachment:image.png)

# %%
# data with an header
df21=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_with_header.csv")

# %%
#here we can see that the column names are not correctly recognized because of that unnecessary header
df22.head()
# Out:
#   unnecessary header     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0            tickers            eps    revenue      price         people
# 1              GOOGL          27.82         87        845     larry page
# 2                WMT           4.61        484         65           n.a.
# 3               MSFT             -1         85         64     bill gates
# 4               RIL   not available         50       1023  mukesh ambani

# %%
#therefore to skip the first row we can use (skiprows=1)
pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_with_header.csv",skiprows=1)
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#another method (header=1)
pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_with_header.csv",header=1)
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %% [markdown]
# ### Suppose you do not have headers (check below image)
# ### How will you do that
# ### and How will you set new column names
# ![image.png](attachment:image.png)

# %%
# here we can see that as because we dont have any header/column names its detecting the first row as our column name
df22=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_no_header.csv")
df22
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
# For this case we have to set (header=None) so that this  dont detect the first row as our column name
pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_no_header.csv",header=None)
# Out:
#        0              1    2     3              4
# 0  GOOGL          27.82   87   845     larry page
# 1    WMT           4.61  484    65           n.a.
# 2   MSFT             -1   85    64     bill gates
# 3   RIL   not available   50  1023  mukesh ambani
# 4   TATA            5.6   -1  n.a.     ratan tata

# %%
# now for setting up new columns
pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_no_header.csv",header=None,names=["TICKER","EPS","REVENUE","PRICE","PEOPLE"])
# Out:
#   TICKER            EPS  REVENUE PRICE         PEOPLE
# 0  GOOGL          27.82       87   845     larry page
# 1    WMT           4.61      484    65           n.a.
# 2   MSFT             -1       85    64     bill gates
# 3   RIL   not available       50  1023  mukesh ambani
# 4   TATA            5.6       -1  n.a.     ratan tata

# %%
# without (header=None) also it will work
pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_no_header.csv",names=["TICKER","EPS","REVENUE","PRICE","PEOPLE"])
# Out:
#   TICKER            EPS  REVENUE PRICE         PEOPLE
# 0  GOOGL          27.82       87   845     larry page
# 1    WMT           4.61      484    65           n.a.
# 2   MSFT             -1       85    64     bill gates
# 3   RIL   not available       50  1023  mukesh ambani
# 4   TATA            5.6       -1  n.a.     ratan tata

# %%
# from stock_data
# suppose we want to read only 3 rows how will you do that
# have to use (nrows=3)
pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data.csv",nrows=3)
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
# here you can see that few columns have irrevalent values 
# have to set them NAN 
df2
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df2_updated=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data.csv",na_values=["not available","n.a."])
df2_updated
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
# here you can see that one more problem is there
# which is in revenue column, if you see that there is -1, which is a bit uncertain
df2_updated=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data.csv",na_values=["not available","n.a.",-1])
df2_updated
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT    NaN     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
# but if you see the eps( earn per share) there is also -1, so if we update -1 in revenue then automatically -1 in esp will get changed, which we dont want because it makes sense
# therefore we can use dictionary to solve this problem
df2_updated=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data.csv",na_values={"eps":["not available","n.a."],
                                                                                                                 "revenue":["not available","n.a.",-1],
                                                                                                                 "price":["not available","n.a."],
                                                                                                                 "people":["not available","n.a."]})
df2_updated
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %% [markdown]
# # header~columns
# # index~ rows

# %%
# here if you see an unnecessary index is arising for that you have to use (index=False)
df2_updated.to_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_updated.csv",index=False)

# %% [markdown]
# ## Day03- 28/07/2024

# %%
# lets import excel file for the same data
import pandas as pd
pd.read_excel("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data.xlsx")
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
# here in people column we want this n.a. to be replaced with name sam walton
# how to do it?
def convert_people_cell(cell):
    if(cell=="n.a."):
        return "sam walton"
    if(cell=="not available"):
        return None
    return cell
df3=pd.read_excel("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data.xlsx",converters={
    "people":convert_people_cell,
    "eps":convert_people_cell
})
df3
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82       87   845     larry page
# 1     WMT   4.61      484    65     sam walton
# 2    MSFT  -1.00       85    64     bill gates
# 3    RIL     NaN       50  1023  mukesh ambani
# 4    TATA   5.60       -1  n.a.     ratan tata

# %%
# how to write an excel file(to_excel)
df3.to_excel("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_excel_updated.xlsx",index=False)

# %% [markdown]
# ### here if you see the output is generating from the top corner
# ### suppose we want to change the starting row and starting column
# ![image.png](attachment:image.png)

# %%
# see how to do that

df3.to_excel("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stock_data_excel_updated2.xlsx",index=False,startrow=3,startcol=2)

# %% [markdown]
# #### startrow=3,startcol=2
# ![image.png](attachment:image.png)

# %%
# suppose you have to set two dataframes in a single excel file in different sheets
data1={"name":["Raj","Lalu","Priya","shiva"],
      "class":[5,6,7,6],
      "sec":["A","B","C","A"],
      "sex":["M","M","M","F"]
      }
data2={"address":["kolkata","santragachi","jadavpur"],
      "pincode":[700124,700122,700101],
      "school_name":["LMS","SQL","TCSM"]}
d1=pd.DataFrame(data1)
d2=pd.DataFrame(data2)

#now have to use (pd.ExcelWriter)

with pd.ExcelWriter("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/two_sheet_file.xlsx") as writer:
    d1.to_excel(writer,sheet_name="data1",index=False)
    d2.to_excel(writer,sheet_name="data2",index=False)

# %% [markdown]
# ### Handling missing values

# %%
df4=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather_data.csv")
df4
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny

# %%
# here in this data there is a problem the column day is not having date time format/type.
type(df4["day"][0])
# Out:
# str

# %%
type(df4.day[0])
# Out:
# str

# %%
# so hace to change this from string to date time format (parse_dates=[" "])
df4=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather_data.csv",parse_dates=["day"])
df4
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
type(df4["day"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# suppose you want to set any column as your index column
# set_index("column_name")

df4.set_index("day")

# %%
# but just by compiling this it wont make sense so you have to do (inplace=True)
df4.set_index("day",inplace=True)
df4
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# how will you fill this NAN values
df4.fillna(0)
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
# but filling out missing values with 0 is not a good practice therefor we have to do something else
#lets fil NAN values 
df4.fillna({"event":"no_event",
           "temperature":0,
           "windspeed":0})
df4
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          0.0        9.0     Sunny
# 2017-01-05         28.0        0.0      Snow
# 2017-01-06          0.0        7.0  no_event
# 2017-01-07         32.0        0.0      Rain
# 2017-01-08          0.0        0.0     Sunny
# 2017-01-09          0.0        0.0  no_event
# 2017-01-10         34.0        8.0    Cloudy
# 2017-01-11         40.0       12.0     Sunny

# %%
# here we can see that it has 0/NAN in few columns so its not a good way of handling missin values
# better we should use (method="bfill"/"ffill")
df4=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather_data.csv",parse_dates=["day"])

df4.ffill()
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         32.0        9.0   Sunny
# 2 2017-01-05         28.0        9.0    Snow
# 3 2017-01-06         28.0        7.0    Snow
# 4 2017-01-07         32.0        7.0    Rain
# 5 2017-01-08         32.0        7.0   Sunny
# 6 2017-01-09         32.0        7.0   Sunny
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df4.bfill()
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04         28.0        9.0   Sunny
# 2 2017-01-05         28.0        7.0    Snow
# 3 2017-01-06         32.0        7.0    Rain
# 4 2017-01-07         32.0        8.0    Rain
# 5 2017-01-08         34.0        8.0   Sunny
# 6 2017-01-09         34.0        8.0  Cloudy
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
# how to remove rows having null values
df4.dropna()
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
# but if any column is not entirely missing i want to preserve those columns
# lets see how to do this
df4.dropna(how="all")

# %%
# suppose if we have atleast one non NAN values then we will not remove the row
df4.dropna(thresh=1)
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
# for 2 
df4=df4.dropna(thresh=2)

# %%
# here you can two dates were added
# keep in mind change first this to date-mont-year format
df42=pd.date_range("01-01-2017","01-11-2017")
idx=pd.DatetimeIndex(df42)
df4=df4.reindex(idx)
df4
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ## Date- 27/07/2024 (Day-4)

# %%
import pandas as pd
import numpy as np
df5=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather_data2.csv")

# %%
# here i want to replace -9999 to nan values
df5.replace(-99999,np.nan)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
# if more than 1 value you want to replace then for eg-31
df5.replace([-99999,31],np.nan)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017          NaN        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df5.replace({"event":"0",
            "temperature":-99999,
            "windspeed":-99999},np.nan)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
df5
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
df5.replace({-99999:np.nan,
            "0":"Sunny"})
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0  Sunny
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0  Sunny

# %%
df55=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather_data3.csv")
df55
# Out:
#           day temperature windspeed  event
# 0  01-01-2017         32F      6MPH   Rain
# 1  01-02-2017          0C         7  Sunny
# 2  01-03-2017          28    -99999   Snow
# 3  01-04-2017          0C         7      0
# 4  01-05-2017          32      7MPH   Rain
# 5  01-06-2017          31         2  Sunny
# 6  01-06-2017          34         5      0

# %%
# suppose your data is mix with numbers and strings which you want to correct by removing the strings
# we use ("[A-Za-z]",regex=True) which is very helpful in finding similar patterns 
# regex~REGULAR EXPRESSION
df55.replace("[A-Za-z]","",regex=True)
# Out:
#           day temperature windspeed event
# 0  01-01-2017          32         6
# 1  01-02-2017           0         7
# 2  01-03-2017          28    -99999
# 3  01-04-2017           0         7     0
# 4  01-05-2017          32         7
# 5  01-06-2017          31         2
# 6  01-06-2017          34         5     0

# %%
# our event column is becoming " " beasuse its also holding string values
# lets try something else
df55.replace({"temperature":"[A-Za-z]","windspeed":"[A-Za-z]"},"",regex=True)
# Out:
#           day temperature windspeed  event
# 0  01-01-2017          32         6   Rain
# 1  01-02-2017           0         7  Sunny
# 2  01-03-2017          28    -99999   Snow
# 3  01-04-2017           0         7      0
# 4  01-05-2017          32         7   Rain
# 5  01-06-2017          31         2  Sunny
# 6  01-06-2017          34         5      0

# %%
# lets now see how to replace a list of values with another list
new_df=pd.DataFrame({"score":["good","average","very_good","poor"],
                    "Student":["rob","piku","rina","tiya"]})
new_df
# Out:
#        score Student
# 0       good     rob
# 1    average    piku
# 2  very_good    rina
# 3       poor    tiya

# %%
new_df.replace(["poor","average","good","very_good"],[1,2,3,4])
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_14804/3408363165.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   new_df.replace(["poor","average","good","very_good"],[1,2,3,4])
#    score Student
# 0      3     rob
# 1      2    piku
# 2      4    rina
# 3      1    tiya

# %% [markdown]
# ## Date- 27/07/2024 (Day-5)

# %% [markdown]
# ### Group By

# %%
import pandas as pd
df6=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather_by_cities.csv")
df6
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
# what is the maximum temperatuere in each of the cities

# %%
g=df6.groupby("city")
g

# %%
# this syntax we should use while using group by statement
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
# suupose if you want to get a specific group
g.get_group("mumbai")
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %% [markdown]
# ![split_apply_combine.png](attachment:split_apply_combine.png)

# %%
# what is the maximum temp in each of the cities
# here you can use anything min,max,avg
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
# what is the average wind speed
g.mean("windspeed")
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
# to get the entire analytics
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# ## Date- 1/08/2024 (Day-6)

# %%
# Concat Data Frames

import pandas as pd
# data 1
india_weather=pd.DataFrame({"city":["mumbai","delhi","banglore"],
                           "temperature":[32,45,30],
                           "humadity": [80,60,78]})

# %%
us_weather=pd.DataFrame({"city":["new_york","chichago","orlando"],
                        "temperature":[21,14,35],
                        "humidity":[68,65,75]})

# %%
dff=pd.concat([india_weather,us_weather])
dff
# Out:
#        city  temperature  humadity  humidity
# 0    mumbai           32      80.0       NaN
# 1     delhi           45      60.0       NaN
# 2  banglore           30      78.0       NaN
# 0  new_york           21       NaN      68.0
# 1  chichago           14       NaN      65.0
# 2   orlando           35       NaN      75.0

# %%
# here you can see that index is coming wrongly so to correct this index, we use (ignore_index=True)
dff=pd.concat([india_weather,us_weather],ignore_index=True)
dff
# Out:
#        city  temperature  humadity  humidity
# 0    mumbai           32      80.0       NaN
# 1     delhi           45      60.0       NaN
# 2  banglore           30      78.0       NaN
# 3  new_york           21       NaN      68.0
# 4  chichago           14       NaN      65.0
# 5   orlando           35       NaN      75.0

# %%
# how to form a group out of this 
# font include ignore_index here or else it will not work
dff=pd.concat([india_weather,us_weather],keys=["india","us"])
dff
# Out:
#              city  temperature  humadity  humidity
# india 0    mumbai           32      80.0       NaN
#       1     delhi           45      60.0       NaN
#       2  banglore           30      78.0       NaN
# us    0  new_york           21       NaN      68.0
#       1  chichago           14       NaN      65.0
#       2   orlando           35       NaN      75.0

# %%
# now simplpy if you want to get the location, we can call any of this we will get that respective subset
dff.loc["india"]
# Out:
#        city  temperature  humadity  humidity
# 0    mumbai           32      80.0       NaN
# 1     delhi           45      60.0       NaN
# 2  banglore           30      78.0       NaN

# %% [markdown]
# #### Appending columns side by side

# %%
# till now we used concat which append rows (axis=0)
# now lets see how to appenad columns side by dide (axis=1)

# %%
temperature=pd.DataFrame({"city":["mumbai","delhi","banglore"],
                         "temperature":[32,45,30]})

# %%
windspeed=pd.DataFrame({"city":["mumbai","delhi","banglore"],
                         "temperature":[7,12,9]})

# %%
df_c=pd.concat([temperature,windspeed],axis=1)
df_c
# Out:
#        city  temperature      city  temperature
# 0    mumbai           32    mumbai            7
# 1     delhi           45     delhi           12
# 2  banglore           30  banglore            9

# %% [markdown]
# ### Many time this happens that in any of the data frame is the column order mqy not match, In such cases the output may come but will come wrongly , check belo
#
# mumbai->delhi  (wrong)

# %%
temperature=pd.DataFrame({"city":["mumbai","delhi","banglore"],
                         "temperature":[32,45,30]})

windspeed=pd.DataFrame({"city":["delhi","banglore","mumbai"],
                         "temperature":[7,12,9]})

df_c1=pd.concat([temperature,windspeed],axis=1)
df_c1
# Out:
#        city  temperature      city  temperature
# 0    mumbai           32     delhi            7
# 1     delhi           45  banglore           12
# 2  banglore           30    mumbai            9

# %%
# so lets see how to corect this
temperature=pd.DataFrame({"city":["mumbai","delhi","banglore"],
                         "temperature":[32,45,30]},index=[1,2,3])

windspeed=pd.DataFrame({"city":["delhi","banglore","mumbai"],
                         "temperature":[7,12,9]},index=[2,3,1])

df_c2=pd.concat([temperature,windspeed],axis=1)
df_c2
# Out:
#        city  temperature      city  temperature
# 1    mumbai           32    mumbai            9
# 2     delhi           45     delhi            7
# 3  banglore           30  banglore           12

# %%
# series (how it works?) lets see
# suppose we want to add more column in this
import pandas as pd
ser=pd.Series(["Humid","Dry","Rain"],name="Event")
ser
# Out:
# 0    Humid
# 1      Dry
# 2     Rain
# Name: Event, dtype: object

# %%
# appending this to temperature
pd.concat([temperature,ser],axis=1)
# Out:
#        city  temperature  Event
# 0    mumbai           32  Humid
# 1     delhi           45    Dry
# 2  banglore           30   Rain

# %% [markdown]
# ### Merge Data Frames
#
# here we have two data frames one containing information about temperature and other containd the information about humidity,
# lets see how we can merge them. Make sure we have to look for a similar column first.

# %%
# merge (let see how merge works?)

import pandas as pd
df_m1=pd.DataFrame({"city":["mumbai","delhi","banglore"],
                         "temperature":[32,45,30]})
df_m1
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
df_m2=pd.DataFrame({"city":["mumbai","delhi","banglore"],
                           "humadity": [80,60,78]})
df_m2
# Out:
#        city  humadity
# 0    mumbai        80
# 1     delhi        60
# 2  banglore        78

# %%
# we are merging on the basis of (city) column
pd.merge(df_m1,df_m2,on="city")
# Out:
#        city  temperature  humadity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %% [markdown]
# ### * it will only give us the result of common column on both the data frames, it gives the intersection of this two data framses
# * inner join - Just by writing pd.merge it results (intersection) by default. or (how = "inner")
#
# * outer join - it gives us the union. (how ="outer")
#
# * left join - it gives all the elements from left as well as intersection of both (how="left")
#
# * right join - it gives all the elements from right as well as intersection of both (how="right)

# %%
# lets see how it workd
df_j1=pd.DataFrame({"city":["new_york","chichago","orlando","baltimore"],
                        "temperature":[21,14,35,32]})
df_j1
# Out:
#         city  temperature
# 0   new_york           21
# 1   chichago           14
# 2    orlando           35
# 3  baltimore           32

# %%
# lets see how it workd
df_j2=pd.DataFrame({"city":["chichago","new_york","sanfrancisco"],
                        "humidity":[65,68,71]})
df_j2
# Out:
#            city  humidity
# 0      chichago        65
# 1      new_york        68
# 2  sanfrancisco        71

# %%
# instersaction 
df_j3=pd.merge(df_j1,df_j2,on="city")
df_j3
# Out:
#        city  temperature  humidity
# 0  new_york           21        68
# 1  chichago           14        65

# %%
# inner join
df_j3=pd.merge(df_j1,df_j2,on="city",how="inner")
df_j3
# Out:
#        city  temperature  humidity
# 0  new_york           21        68
# 1  chichago           14        65

# %%
# left
df_j3=pd.merge(df_j1,df_j2,on="city",how="left")
df_j3
# Out:
#         city  temperature  humidity
# 0   new_york           21      68.0
# 1   chichago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           32       NaN

# %%
df_j3=pd.merge(df_j1,df_j2,on="city",how="right")
df_j3
# Out:
#            city  temperature  humidity
# 0      chichago         14.0        65
# 1      new_york         21.0        68
# 2  sanfrancisco          NaN        71

# %%
df_j3=pd.merge(df_j1,df_j2,on="city",how="outer")
df_j3
# Out:
#            city  temperature  humidity
# 0     baltimore         32.0       NaN
# 1      chichago         14.0      65.0
# 2      new_york         21.0      68.0
# 3       orlando         35.0       NaN
# 4  sanfrancisco          NaN      71.0

# %%
# if you want to see from where this came for that we can use (indicator=True)
df_j3=pd.merge(df_j1,df_j2,on="city",how="outer",indicator=True)
df_j3
# Out:
#            city  temperature  humidity      _merge
# 0     baltimore         32.0       NaN   left_only
# 1      chichago         14.0      65.0        both
# 2      new_york         21.0      68.0        both
# 3       orlando         35.0       NaN   left_only
# 4  sanfrancisco          NaN      71.0  right_only

# %%
df_j3=pd.DataFrame({"city":["mumbai","delhi","banglore"],
                    "hunidity":[10,11,12],
                         "temperature":[32,45,30]})

df_j4=pd.DataFrame({"city":["delhi","banglore","mumbai"],
                    "hunidity":[15,11,19],
                         "temperature":[7,12,9]})

# %% [markdown]
# ### when you have same set of columns check what happens
# ### It automatically creates seperate column by itself

# %%
pd.merge(df_j3,df_j4,on="city")
# Out:
#        city  hunidity_x  temperature_x  hunidity_y  temperature_y
# 0    mumbai          10             32          19              9
# 1     delhi          11             45          15              7
# 2  banglore          12             30          11             12

# %% [markdown]
#   ### pivot in pandas

# %%
import pandas as pd
df_p=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather.csv")
df_p
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df_p.pivot(index="date",columns="city")
# Out:
#          temperature                 humidity
# city         beijing mumbai new york  beijing mumbai new york
# date
# 5/1/2017          80     75       65       26     80       56
# 5/2/2017          77     78       66       30     83       58
# 5/3/2017          79     82       68       35     85       60

# %% [markdown]
# ### pivot table

# %%
# for this tabl for the same the date multiple column because maybe morning/afternoon temperature, so now create a data frame which contains the average temperature throughout the day
import pandas as pd
df_p=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather2.csv")
df_p
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/1/2017  new york           61        54
# 2  5/2/2017  new york           70        60
# 3  5/2/2017  new york           72        62
# 4  5/1/2017    mumbai           75        80
# 5  5/1/2017    mumbai           78        83
# 6  5/2/2017    mumbai           82        85
# 7  5/2/2017    mumbai           80        26

# %%
# we have to use aggregate function (aggfunc) 
# the defualt aggregate function is set to mean
df_p.pivot_table(index="city",columns="date",aggfunc="mean")
# Out:
#          humidity          temperature
# date     5/1/2017 5/2/2017    5/1/2017 5/2/2017
# city
# mumbai       81.5     55.5        76.5     81.0
# new york     55.0     61.0        63.0     71.0

# %%
# for set a margin use (margins=True)
# inside ALL you able to see the average between those two dates
df_p.pivot_table(index="city",columns="date",aggfunc="mean",margins=True)
# Out:
#          humidity                 temperature
# date     5/1/2017 5/2/2017    All    5/1/2017 5/2/2017     All
# city
# mumbai      81.50    55.50  68.50       76.50     81.0  78.750
# new york    55.00    61.00  58.00       63.00     71.0  67.000
# All         68.25    58.25  63.25       69.75     76.0  72.875

# %% [markdown]
# ### Adding 3rd data

# %%
df_p1=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather3.csv")

df_p1
# Out:
#         date      city  temperature  humidity
# 0   5/1/2017  new york           65        56
# 1   5/2/2017  new york           61        54
# 2   5/3/2017  new york           70        60
# 3  12/1/2017  new york           30        50
# 4  12/2/2017  new york           28        52
# 5  12/3/2017  new york           25        51

# %%
type(df_p1["date"][0])
# Out:
# str

# %% [markdown]
# ### Here the date is in string we have to change that to date first.

# %%
df_p1["date"]=pd.to_datetime(df_p1["date"])

# %%
type(df_p1["date"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %% [markdown]
# ## Date- 1/08/2024 (Day-7)

# %%
import pandas as pd
df_reshape=pd.read_csv("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/weather_reshape.csv")
df_reshape
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
# here i want to peform ( melt ) funtion
# (id_vars=" ") here we set the variable name which will going to be x-axis

df_reshape1=pd.melt(df_reshape,id_vars='day')
df_reshape1
# Out:
#           day variable  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
# suppose you want to get only one varible results

df_reshape2=pd.melt(df_reshape,id_vars='day')
df_reshape2[df_reshape1["variable"]=="chicago"]
# Out:
#          day variable  value
# 0     Monday  chicago     32
# 1    Tuesday  chicago     30
# 2  Wednesday  chicago     28
# 3   Thursday  chicago     22
# 4     Friday  chicago     30
# 5   Saturday  chicago     20
# 6     Sunday  chicago     25

# %%
# here if you see the column names are coming wrngly so lets correct that

df_reshape3=pd.melt(df_reshape,id_vars='day',var_name="City",value_name="Temperature")
df_reshape3
# Out:
#           day     City  Temperature
# 0      Monday  chicago           32
# 1     Tuesday  chicago           30
# 2   Wednesday  chicago           28
# 3    Thursday  chicago           22
# 4      Friday  chicago           30
# 5    Saturday  chicago           20
# 6      Sunday  chicago           25
# 7      Monday  chennai           75
# 8     Tuesday  chennai           77
# 9   Wednesday  chennai           75
# 10   Thursday  chennai           82
# 11     Friday  chennai           83
# 12   Saturday  chennai           81
# 13     Sunday  chennai           77
# 14     Monday   berlin           41
# 15    Tuesday   berlin           43
# 16  Wednesday   berlin           45
# 17   Thursday   berlin           38
# 18     Friday   berlin           30
# 19   Saturday   berlin           45
# 20     Sunday   berlin           47

# %% [markdown]
# ### Stack & Unstack
#
# #### Stack takes the inner most level and transpose it

# %%
df_reshape4=pd.read_excel("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stocks.xlsx")
df_reshape4
# Out:
#             Unnamed: 0     Price Unnamed: 2 Unnamed: 3  \
# 0              Company  Facebook     Google  Microsoft
# 1  2017-06-05 00:00:00       155        955         66
# 2  2017-06-06 00:00:00       150        987         69
# 3  2017-06-07 00:00:00       153        963         62
# 4  2017-06-08 00:00:00       155       1000         61
# 5  2017-06-09 00:00:00       156       1012         66
#
#   Price to earnings ratio (P/E) Unnamed: 5 Unnamed: 6
# 0                      Facebook     Google  Microsoft
# 1                          37.1         32      30.31
# 2                         36.98       31.3      30.56
# 3                         36.78       31.7      30.46
# 4                         36.11       31.2      30.11
# 5                         37.07         30         31

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_reshape4=pd.read_excel("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stocks.xlsx",header=[0,1])
df_reshape4
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %% [markdown]
# ### here we want to change the position of rows to columns and column to rows

# %%
# this way we cant not do
# df_reshape5=pd.melt(df_reshape4,id_vars="")

# %%
# have to use stack

df_stacked=df_reshape4.stack()
df_stacked
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_18012/1421395329.py:3: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stacked=df_reshape4.stack()
#             Unnamed: 0_level_0   Price  Price to earnings ratio (P/E)
# 0 Company           2017-06-05     NaN                            NaN
#   Facebook                 NaT   155.0                          37.10
#   Google                   NaT   955.0                          32.00
#   Microsoft                NaT    66.0                          30.31
# 1 Company           2017-06-06     NaN                            NaN
#   Facebook                 NaT   150.0                          36.98
#   Google                   NaT   987.0                          31.30
# ...

# %%
# you can include level=1, dropna=True) inside this
df_reshape4.stack(level=0)
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_18012/913938778.py:2: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_reshape4.stack(level=0)
#                                    Company  Facebook  Google  Microsoft
# 0 Price                                NaT    155.00   955.0      66.00
#   Price to earnings ratio (P/E)        NaT     37.10    32.0      30.31
#   Unnamed: 0_level_0            2017-06-05       NaN     NaN        NaN
# 1 Price                                NaT    150.00   987.0      69.00
#   Price to earnings ratio (P/E)        NaT     36.98    31.3      30.56
#   Unnamed: 0_level_0            2017-06-06       NaN     NaN        NaN
# 2 Price                                NaT    153.00   963.0      62.00
# ...

# %%
# to get the original data frame back

df_stacked.unstack()
# Out:
#   Unnamed: 0_level_0                             Price                   \
#              Company Facebook Google Microsoft Company Facebook  Google
# 0         2017-06-05      NaT    NaT       NaT     NaN    155.0   955.0
# 1         2017-06-06      NaT    NaT       NaT     NaN    150.0   987.0
# 2         2017-06-07      NaT    NaT       NaT     NaN    153.0   963.0
# 3         2017-06-08      NaT    NaT       NaT     NaN    155.0  1000.0
# 4         2017-06-09      NaT    NaT       NaT     NaN    156.0  1012.0
#
#             Price to earnings ratio (P/E)
#   Microsoft                       Company Facebook Google Microsoft
# 0      66.0                           NaN    37.10   32.0     30.31
# 1      69.0                           NaN    36.98   31.3     30.56
# 2      62.0                           NaN    36.78   31.7     30.46
# 3      61.0                           NaN    36.11   31.2     30.11
# 4      66.0                           NaN    37.07   30.0     31.00

# %%
# when you will be having 3 level of header
# header=[0,1,2]
df_reshape6=pd.read_excel("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/stocks_3_levels.xlsx",header=[0,1,2])
df_reshape6
# Out:
#   Unnamed: 0_level_0 Price Ratios                   \
#   Unnamed: 0_level_1        Price
#              Company     Facebook Google Microsoft
# 0            Q1 2016          155    955        66
# 1            Q2 2016          150    987        69
# 2            Q3 2016          153    963        62
# 3            Q4 2016          155   1000        61
# 4            Q1 2017          156   1012        66
#
#                                                  Income Statement         \
#   Price to earnings ratio (P/E)                         Net Sales
#                        Facebook Google Microsoft         Facebook Google
# 0                         37.10   32.0     30.31              2.6     20
# 1                         36.98   31.3     30.56              3.1     22
# 2                         36.78   31.7     30.46              4.3     24
# 3                         36.11   31.2     30.11              6.7     26
# ...

# %%
df_reshape6.stack(level=0)
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_18012/1830054933.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_reshape6.stack(level=0)
#                      Unnamed: 0_level_1    Price                    \
#                                 Company Facebook  Google Microsoft
# 0 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    155.0   955.0      66.0
#   Unnamed: 0_level_0            Q1 2016      NaN     NaN       NaN
# 1 Income Statement                  NaN      NaN     NaN       NaN
#   Price Ratios                      NaN    150.0   987.0      69.0
#   Unnamed: 0_level_0            Q2 2016      NaN     NaN       NaN
# 2 Income Statement                  NaN      NaN     NaN       NaN
# ...

# %%
df_reshape6.stack(level=1)
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_18012/3126521186.py:1: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_reshape6.stack(level=1)
#                                 Unnamed: 0_level_0 Price Ratios          \
#                                            Company     Facebook  Google
# 0 Net Profit                                   NaN          NaN     NaN
#   Net Sales                                    NaN          NaN     NaN
#   Price                                        NaN       155.00   955.0
#   Price to earnings ratio (P/E)                NaN        37.10    32.0
#   Unnamed: 0_level_1                       Q1 2016          NaN     NaN
# 1 Net Profit                                   NaN          NaN     NaN
# ...

# %%
# df_reshape.unstack()
df_reshape6.stack(level=2)
# Out:
# C:\Users\ritti\AppData\Local\Temp/ipykernel_18012/1086026016.py:2: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_reshape6.stack(level=2)
#             Unnamed: 0_level_0 Price Ratios                                \
#             Unnamed: 0_level_1        Price Price to earnings ratio (P/E)
# 0 Company              Q1 2016          NaN                           NaN
#   Facebook                 NaN        155.0                         37.10
#   Google                   NaN        955.0                         32.00
#   Microsoft                NaN         66.0                         30.31
# 1 Company              Q2 2016          NaN                           NaN
#   Facebook                 NaN        150.0                         36.98
# ...

# %%
df_reshape6.unstack()
# Out:
# Unnamed: 0_level_0  Unnamed: 0_level_1  Company    0    Q1 2016
#                                                    1    Q2 2016
#                                                    2    Q3 2016
#                                                    3    Q4 2016
#                                                    4    Q1 2017
#                                                          ...
# Income Statement    Net Profit          Microsoft  0       4.56
#                                                    1        5.1
#                                                    2       5.43
#                                                    3       5.89
#                                                    4       6.09
# Length: 65, dtype: object

# %% [markdown]
# ## Contingency table
#
# ### Crosstab

# %%
df_cross=pd.read_excel("C:/Users/ritti/Downloads/internal_skill_stuff/prac_python/Data/survey.xls")

df_cross
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
#lets set a crosstab for nationality and handedness

# %%
df_cross1=pd.crosstab(df_cross["Nationality"],df_cross["Handedness"])

df_cross1
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
# if you want to see the all total value also we nee to use margins=True

df_cross1=pd.crosstab(df_cross["Nationality"],df_cross["Handedness"],margins=True)

df_cross1
# Out:
# Handedness   Left  Right  All
# Nationality
# Bangadesh       2      0    2
# China           2      1    3
# India           2      1    3
# USA             1      3    4
# All             7      5   12

# %%
# when you want to add in crosstab more than one element in rows or columns 
pd.crosstab(df_cross["Nationality"],[df_cross["Handedness"],df_cross["Sex"]],margins=True)
# Out:
# Handedness    Left       Right      All
# Sex         Female Male Female Male
# Nationality
# Bangadesh        1    1      0    0   2
# China            1    1      1    0   3
# India            0    2      0    1   3
# USA              0    1      2    1   4
# All              2    5      3    2  12

# %%
pd.crosstab([df_cross["Nationality"],df_cross["Sex"]],df_cross["Handedness"],margins=True)
# Out:
# Handedness          Left  Right  All
# Nationality Sex
# Bangadesh   Female     1      0    1
#             Male       1      0    1
# China       Female     1      1    2
#             Male       1      0    1
# India       Male       2      1    3
# USA         Female     0      2    2
#             Male       1      1    2
# All                    7      5   12

# %%
# margins=True
pd.crosstab(df_cross["Nationality"],df_cross["Handedness"],margins=True)
# Out:
# Handedness   Left  Right  All
# Nationality
# Bangadesh       2      0    2
# China           2      1    3
# India           2      1    3
# USA             1      3    4
# All             7      5   12

# %%
# to n`ormalize this values
pd.crosstab(df_cross["Nationality"],df_cross["Handedness"],normalize=True)
# Out:
# Handedness       Left     Right
# Nationality
# Bangadesh    0.166667  0.000000
# China        0.166667  0.083333
# India        0.166667  0.083333
# USA          0.083333  0.250000

# %%
# lets see the average age of left handed, right handed persons 
import numpy as np
pd.crosstab(df_cross["Nationality"],df_cross["Handedness"],values=df_cross["Age"],aggfunc=np.average)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh    28.0    NaN
# China        50.5   52.0
# India        33.0   37.0
# USA          22.0   20.0
